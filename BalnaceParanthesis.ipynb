# %%
class Stack:
    def __init__(self):
        self.a=[];

    def push(self,item):
        self.a.append(item)
        print("pushed - (")

    def pop(self):
        item=self.a.pop()
        print("popped - )")

    def length(self):
        return len(self.a)

    def print(self):
        print("stack : ",self.a)
    
    def isEmpty(self):
        return len(self.a)==0

def balancePara(arr):
    i=0;
    s1=Stack()
    while i<len(arr):
       if(arr[i]=='('):
           s1.push('(')
       elif(arr[i]==')'):
           if(s1.isEmpty()):
               print("popped - )")
               return 0;
           else:
               s1.pop();
       i+=1;

    if(s1.isEmpty()):
        return 1

print("first test case \n")
if balancePara("(())"):
    print("String is balanced")
else:
    print("String is unbalanced")

print("first test case \n")
if balancePara(")"):
    print("String is balanced")
else:
    print("String is unbalanced")

print("first test case \n")
if balancePara(""):
    print("String is balanced")
else:
    print("String is unbalanced")

print("first test case \n")
if balancePara("(()))"):
    print("String is balanced")
else:
    print("String is unbalanced")
  
print("first test case \n")
if balancePara("((())"):
    print("String is balanced")
else:
    print("String is unbalanced")

print("first test case \n")
if balancePara("((()))((()))"):
    print("String is balanced")
else:
    print("String is unbalanced")
# Out:
# pushed - (
# pushed - (
# popped - )
# popped - )
# String is balanced
# popped - )
# String is unbalanced
# String is balanced
# pushed - (
# pushed - (
# popped - )
# popped - )
# popped - )
# String is unbalanced
# pushed - (
# pushed - (
# pushed - (
# popped - )
# popped - )
# String is unbalanced
# pushed - (
# pushed - (
# pushed - (
# popped - )
# popped - )
# popped - )
# pushed - (
# pushed - (
# pushed - (
# popped - )
# popped - )
# popped - )
# String is balanced
